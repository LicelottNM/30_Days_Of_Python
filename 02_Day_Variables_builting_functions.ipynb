# %% [markdown]
# Day 2 - Variables builting functions

# %%
help('keywords')
# Out:
# Here is a list of the Python keywords.  Enter any keyword to get more help.
#
# False               class               from                or
# None                continue            global              pass
# True                def                 if                  raise
# and                 del                 import              return
# as                  elif                in                  try
# assert              else                is                  while
# async               except              lambda              with
# await               finally             nonlocal            yield
# break               for                 not
#
# No Python documentation found for 'key wods'.
# Use help() to get the interactive help utility.
# Use help(str) for help on the str class.

# %%
help('pandas')

# %%
# common functions
len('Licelott')
type(5)
str(10)
int('10')
float(10)
input('Enter your name:')

# %%
# different ways to use functions
min(30,30,40,20) # -> take the minimum value from the list
max(30,30,40,20) # -> take the maximum value from the list
sum([30,30,40,20]) # -> take the sum of the values in the list

# %% [markdown]
# Python Variable Name Rules
#
# A variable name must start with a letter or the underscore character
# A variable name cannot start with a number
# A variable name can only contain alpha-numeric characters and underscores (A-z, 0-9, and _ )
# Variable names are case-sensitive (firstname, Firstname, FirstName and FIRSTNAME) are different variables)

# %%
# Variables iun python
first_name ='Licelott'
last_name = 'noboa'
country = 'Dominican Republic'
age = 23
is_married = False # if we want to use reserved word as a variable we can add an underscore at the end of the variable name
skills = ['python', 'sql', 'power bi', 'excel']

person_info = {
    'first_name': 'Licelott',
    'last_name': 'noboa',
    'country': 'Dominican Republic',
    'age': 23,
    'is_married': False,
    'skills': ['python', 'sql', 'power bi', 'excel']
}

# %%
# Invalid variables names

first-name = 'Licelott'
first@name = 'Licelott'
first$name = 'Licelott'
num-1 = 1
1num = 1

# %%
# Printing the values stored in the variables
print('first_name:', first_name)
print('last_name:', last_name)
print('country:', country)
# Out:
# first_name: Licelott
# last_name: noboa
# country: Dominican Republic

# %%
# Declaring Multiple Variable in a Line

print(first_name, age, country)
# Out:
# Licelott 23 Dominican Republic

# %%
# input function
first_name = input('what is your name: ')
age = input('How old are you; ')

print(first_name)
print(age)
# Out:
# juan
# 26

# %%
# Converting 

num_int = 10
print('num_int',num_int)
num_float = float(num_int) # -> converting integer to float
print('num_float',num_float)

gravity = 9.81
print(int(gravity)) # -> converting float to integer, it will take the whole number and ignore the decimal part

num_int2 = 10
num_str = str(num_int2) # -> converting integer to string
print(type(num_str))

first_name = 'Licelott'
print(first_name)
first_name_list = list(first_name) # -> converting string to list, it will take each character in the string and make it an element in the list
print(first_name_list)
# Out:
# num_int 10
# num_float 10.0
# 9
# <class 'str'>
# Licelott
# ['L', 'i', 'c', 'e', 'l', 'o', 't', 't']

# %% [markdown]
# Exercises

# %%
# Inside 30DaysOfPython create a folder called day_2. Inside this folder create a file named variables.py
# Write a python comment saying 'Day 2: 30 Days of python programming'
# day 2 : of python programing
# Declare a first name variable and assign a value to it
# Declare a full name variable and assign a value to it
# Declare a country variable and assign a value to it
# Declare a city variable and assign a value to it
# Declare an age variable and assign a value to it
# Declare a year variable and assign a value to it
# Declare a variable is_married and assign a value to it
# Declare a variable is_true and assign a value to it
# Declare a variable is_light_on and assign a value to it
# Declare multiple variable on one line

# %% [markdown]
# Exercises level 2

# %%
# Check the data type of all your variables using type() built-in function.
number = 10
print(type(number))
# Out:
# <class 'int'>

# %%
# Using the len() built-in function, find the length of your first name
first_name = 'Licleott'
print(len(first_name))
# Out:
# 8

# %%
# Compare the length of your first name and your last nam
first_name = 'Licelott'
last_name = 'Noboa'

print(len(first_name))
print(len(last_name))
# Out:
# 8
# 5

# %%
# Declare 5 as num_one and 4 as num_two
num_one = 5
num_two = 4

# %%
# Add num_one and num_two and assign the value to a variable total
total = num_one + num_two
print(total)
# Out:
# 9

# %%
# Subtract num_two from num_one and assign the value to a variable diff
diff = num_one - num_two
print(diff)
# Out:
# 1

# %%
# Multiply num_two and num_one and assign the value to a variable product
product = num_one * num_two
print(product)
# Out:
# 20

# %%
# Divide num_one by num_two and assign the value to a variable division
division = num_one / num_two
print(division)
# Out:
# 1.25

# %%
# Use modulus division to find num_two divided by num_one and assign the value to a variable remainder
remainder = num_two % num_one
print(remainder)
# Out:
# 1

# %%
# Calculate num_one to the power of num_two and assign the value to a variable exp
exp = num_one ** num_two
print(exp)
# Out:
# 625

# %%
# Find floor division of num_one by num_two and assign the value to a variable floor_division
floor_division = num_one // num_two
print(floor_division)
# Out:
# 1

# %%
# The radius of a circle is 30 meters.
# Calculate the area of a circle and assign the value to a variable name of area_of_circle
# Calculate the circumference of a circle and assign the value to a variable name of circum_of_circle
# Take radius as user input and calculate the area.

radius = float(input("Enter the radius of the circle: "))
area_of_circle = 3.14 * radius ** 2
circum_of_circle = 2 * 3.14 * radius
print("Area of the circle:", area_of_circle)
print("Circumference of the circle:", circum_of_circle)
# Out:
# Area of the circle: 12.56
# Circumference of the circle: 12.56

# %%
# Use the built-in input function to get first name, last name, country and age from a user and store the value to their corresponding variable names
first_name = input('What is your name;')
last_name = input('What is your l;ast name')
country = input('Where do you live')
age = input('How old are you')

print(first_name)
print(last_name)
print(country)
print(age)
# Out:
# lis
# noboa
# santo domingo
# 23

# %%
# Run help('keywords') in Python shell or in your file to check for the Python reserved words or keywords
help('keywords')
# Out:
# Here is a list of the Python keywords.  Enter any keyword to get more help.
#
# False               class               from                or
# None                continue            global              pass
# True                def                 if                  raise
# and                 del                 import              return
# as                  elif                in                  try
# assert              else                is                  while
# async               except              lambda              with
# await               finally             nonlocal            yield
# break               for                 not
