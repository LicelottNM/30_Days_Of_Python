# %% [markdown]
# Day 3 - Operators

# %% [markdown]
# Boolean

# %%
# A boolean represents True or False
print(type(True))
print(type(False))
# Out:
# <class 'bool'>
# <class 'bool'>

# %% [markdown]
# Operators

# %% [markdown]
# Assigment operators
#
# Assignment operators are used to assign values to variables
#
#         can be =, +=, -=, *=, /=, %=, //=, **=, &=, |=, ^=, >>=, <<= and more

# %% [markdown]
# Arithmetic Operators
#
#         Can be +, -, *, /, %, **, //,

# %%
# Declaring a variable
a = 3
b = 6

# arithmetic operators
total = a + b
diff = a - b
product = a * b
division = a / b
remainder = a % b
floor_division = a // b
exponential = a ** b

# If you mark some string in the print you can reemember the result coming from 
print('Total:', total)
print('Difference:', diff)
print('Product:', product)
print('Division:', division)
print('Remainder:', remainder)
print('Floor Division:', floor_division)
print('Exponential:', exponential)
# Out:
# Total: 9
# Difference: -3
# Product: 18
# Division: 0.5
# Remainder: 3
# Floor Division: 0
# Exponential: 729

# %% [markdown]
# Comparison Operators
#
#         Can be == equal, != Not equal, > greater than, < less than, >= greather than or equal to, <= less than or equal to

# %%
# comparison operators with each simbols
print(3 > 2) # true, because 3 is greater than 2
print(3 < 2) # false, because 3 is not less than 2
print(3 >= 2) # true, because 3 is greater than or equal to 2
print(3 <= 2) # false, because 3 is not less than or equal to 2
print(3 == 2) # false, because 3 is not equal to 2
print(3 != 2) # true, because 3 is not equal to 2
# Out:
# True
# False
# True
# False
# False
# True
# False

# %%
# comparison operators with strings
print('mango' > 'apple') # true, because 'm' comes after 'a' in the alphabet
print(len('manzana') == len('aji')) # false, because 7 is not equal to 3
# Out:
# True
# False

# %%
# Comparing something gives either a True or False
print('true == true:', True == True) # true, because both sides are true
print('true == false:', True == False) # false, because one side is true and the other is false
print('false == false:', False == False) # true, because both sides are false
# Out:
# true == true: True
# true == false: False
# false == false: True

# %%
print('1 is 1', 1 is 1)                   # True - because the data values are the same
print('1 is not 2', 1 is not 2)           # True - because 1 is not 2
print('A in Asabeneh', 'A' in 'Asabeneh') # True - A found in the string
print('B not in Asabeneh', 'B' in 'Asabeneh') # False - there is no uppercase B
print('coding' in 'coding for all') # True - because coding for all has the word coding
print('a in an:', 'a' in 'an')      # True
print('4 is 2 ** 2:', 4 is 2 ** 2)   # True

# %% [markdown]
# Logical Operators
#
#         Can be and, or, not

# %%
print(3 > 2 and 4 > 3) # True - because both statements are true
print(3 > 2 and 4 < 3) # False - because the second statement is false
print(3 < 2 and 4 < 3) # False - because both statements are false
print('True and True: ', True and True)
print(3 > 2 or 4 > 3)  # True - because both statements are true
print(3 > 2 or 4 < 3)  # True - because one of the statements is true
print(3 < 2 or 4 < 3)  # False - because both statements are false
print('True or False:', True or False)
print(not 3 > 2)     # False - because 3 > 2 is true, then not True gives False
print(not True)      # False - Negation, the not operator turns true to false
print(not False)     # True
print(not not True)  # True
print(not not False) # False
# Out:
# True
# False
# False
# True and True:  True
# True
# True
# False
# True or False: True
# False
# False
# True
# True
# False

# %% [markdown]
# Exercises Day 3

# %%
# Declare your age as integer variable
age = 23
print(age)
# Out:
# 23

# %%
# Declare your height as a float variable
height = 1.5
print(height)
# Out:
# 1.5

# %%
# Declare a variable that store a complex number
print('complex', 1+1j)
# Out:
# complex (1+1j)

# %%
# Write a script that prompts the user to enter base and height of the triangle and calculate an area of this triangle (area = 0.5 x b x h).
base = float(input('Enter base'))
height = float(input('Enter height'))

area = 0.5 * base * height

print('the area of the triangle is', area)
# Out:
# the area of the triangle is 100.0

# %%
# Write a script that prompts the user to enter side a, side b, and side c of the triangle. Calculate the perimeter of the triangle (perimeter = a + b + c).
side_a = int(input('Enter side a'))
side_b = int(input('Enter side b'))
side_c = int(input('Enter side c'))

perimeter = side_a + side_b + side_c

print('the perimeter is', perimeter)
# Out:
# the perimeter is 12

# %%
# Get length and width of a rectangle using prompt. Calculate its area (area = length x width) and perimeter (perimeter = 2 x (length + width))
length = int(input('Enter lenght of the triangle'))
width = int(input('Enter width of the triangle'))

area = length * width
perimeter = 2 * (length + width)

print('the area of the triangle is', area)
print('the perimeter of the triangle is', perimeter)
# Out:
# the area of the triangle is 15
# the perimeter of the triangle is 16

# %%
#Get radius of a circle using prompt. 
# Calculate the area (area = pi x r x r) and circumference (c = 2 x pi x r) where pi = 3.14.
radius = float(input(' Enter the radius of the circle'))

area = 3.14 * radius * radius
circumference= 2.0 * 3.14 * radius

print('the area of the circle is', area)
print('the circumference of the circle is', circumference)
# Out:
# the area of the circle is 1256.0
# the circumference of the circle is 125.60000000000001
