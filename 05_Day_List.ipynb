# %%
#💻 Exercises: Day 5

# %%
#Exercises: Level 1

# %%
#Declare an empty list
empty = [] #No se puede poner cosas dentro como , por ejemplo

print (empty)
# Out:
# []

# %%
#Declare a list with more than 5 items
more_5 = ["uno", "dos", "tres", "cuatro", "cinco", "seis"]

print(more_5)
# Out:
# ['uno', 'dos', 'tres', 'cuatro', 'cinco', 'seis']

# %%
#Find the length of your list
len(more_5)
# Out:
# 6

# %%
#Get the first item, the middle item and the last item of the list
first_item = more_5[0]
middle_item = more_5[len(more_5)//2] # toma el elemento, cuenta la cantidad de items y dividelo en 2 -> esto da el numero del medio
last_item = more_5[-1]

print(first_item)
print(middle_item)
print(last_item)

# las listas comienzan en 0 a contar, no en 1
# Out:
# uno
# cuatro
# seis

# %%
#Declare a list called mixed_data_types, put your(name, age, height, marital status, address)
mixed_data_types = ["Liss", 23, 5.1, False, "Call San Jose, 12"] # para que sea booleano no puede tener ""

print(mixed_data_types)
# Out:
# ['Liss', 23, 5.1, False, 'Call San Jose, 12']

# %%
# Declare a list variable named it_companies and assign initial values Facebook, Google, Microsoft, Apple, IBM, Oracle and Amazon.

it_companies = ["Facebook", "Google", "Microsoft", "Apple", "IBM", "Oracle", "Amazon"]

print("companies:",it_companies)
# Out:
# companies: ['Facebook', 'Google', 'Microsoft', 'Apple', 'IBM', 'Oracle', 'Amazon']

# %%
# Print the list using print()
print(it_companies)
# Out:
# ['Facebook', 'Google', 'Microsoft', 'Apple', 'IBM', 'Oracle', 'Amazon']

# %%
# Print the number of companies in the list
len(it_companies)
# Out:
# 7

# %%
# Print the first, middle and last company
first_company = it_companies[0]
middle_company = it_companies[len(it_companies) // 2]
last_company = it_companies[-1]

print(first_company)
print(middle_company)
print(last_company)
# Out:
# Facebook
# Apple
# Amazon

# %%
# Print the list after modifying one of the companies
it_companies[0] = "Meta" # de esta forma cambio el valor sin listar nuevamente, solo elijo la posicion

print(it_companies)
# Out:
# ['Meta', 'Google', 'Microsoft', 'Apple', 'IBM', 'Oracle', 'Amazon']

# %%
# Add an IT company to it_companies
it_companies.append("Mitsubichi") # se usa mas el append
it_companies = it_companies + ["Honda"]
print(it_companies)
# Out:
# ['Meta', 'Google', 'Microsoft', 'Apple', 'IBM', 'Oracle', 'Amazon', 'Mitsubichi', 'Honda']

# %%
#Insert an IT company in the middle of the companies list
#it_companies = it_companies[len(it_companies) // 2] + ["Coca cola"] -> mi error

it_companies.insert(len(it_companies)//2, "Coca cola")

print(it_companies)

# si le doy dos veces se agrega las veces que les de
# Out:
# ['Meta', 'Google', 'Microsoft', 'Apple', 'Coca cola', 'IBM', 'Oracle', 'Amazon', 'Mitsubichi', 'Honda']

# %%
# Aqui removi un valor, si hay mas de un valor asi entonces se remueve una vez

it_companies.remove("Coca cola")
print(it_companies)

# otra opcion mas larga seria esta
#  it_companies = [c for c in it_companies if c != "Coca cola"] -> mas avanzada
# Out:
# ['Meta', 'Google', 'Microsoft', 'Apple', 'IBM', 'Oracle', 'Amazon', 'Mitsubichi', 'Honda']

# %%
print(it_companies)
# Out:
# ['Meta', 'Google', 'Microsoft', 'Apple', 'IBM', 'Oracle', 'Amazon', 'Mitsubichi', 'Honda']

# %%
# Change one of the it_companies names to uppercase (IBM excluded!)
    # it_companies.uppercase("Honda") -> baddd way

index = it_companies.index("Google") # busca donde esta el valor y guarda esa posicion
it_companies[index] = it_companies[index].upper() # En esta posicion toma el texto y pasalo a mayuscula

print(it_companies)
# Out:
# ['Meta', 'GOOGLE', 'Microsoft', 'Apple', 'IBM', 'Oracle', 'Amazon', 'Mitsubichi', 'Honda']

# %%
# Change one of the it_companies names to lowercase (IBM excluded!)
index = it_companies.index("Meta")
it_companies[index] = it_companies[index].lower()

print(it_companies)
# Out:
# ['meta', 'GOOGLE', 'Microsoft', 'Apple', 'IBM', 'Oracle', 'Amazon', 'Mitsubichi', 'Honda']

# %%
# Change one of the it_companies names to capitalize (IBM excluded!)
index = it_companies.index("meta")
it_companies[index] = it_companies[index].capitalize()

print(it_companies)
# Out:
# ['Meta', 'GOOGLE', 'Microsoft', 'Apple', 'IBM', 'Oracle', 'Amazon', 'Mitsubichi', 'Honda']

# %%
# Join the it_companies with a string '#;  '

result = ';  '.join(it_companies)

print(result)
type(result)
# Out:
# Meta;  GOOGLE;  Microsoft;  Apple;  IBM;  Oracle;  Amazon;  Mitsubichi;  Honda
# str

# %%
# Check if a certain company exists in the it_companies list.
"Carlos" in it_companies
# Out:
# False

# %%
"Coca cola" in it_companies
# Out:
# False

# %%
# Sort the list using sort() method
    # organize_list = it_companies.sort() -> casi pero no
    # otra forma es -> it_companies.sort()

organize_list = sorted(it_companies)

print(organize_list)
# Out:
# ['Amazon', 'Apple', 'GOOGLE', 'Honda', 'IBM', 'Meta', 'Microsoft', 'Mitsubichi', 'Oracle']

# %%
# Reverse the list in descending order using reverse() method
    # it_companies.reverse() -> esta es la forma facil y rapida

order_organize_list = list(reversed(it_companies))

print(order_organize_list)
# Out:
# ['Honda', 'Mitsubichi', 'Amazon', 'Oracle', 'IBM', 'Apple', 'Microsoft', 'GOOGLE', 'Meta']

# %%
# Slice out the first 3 companies from the list
it_companies[0:3]
# Out:
# ['Meta', 'GOOGLE', 'Microsoft']

# %%
# Slice out the last 3 companies from the list
it_companies[-3:]
# Out:
# ['Amazon', 'Mitsubichi', 'Honda']

# %%
# Slice out the middle IT company or companies from the list
    # it_companies[(it_companies.len()//2):-1]

it_companies[len(it_companies)//2]
# Out:
# 'IBM'

# %%
# Remove the first IT company from the list
it_companies.pop(0)
# Out:
# 'Meta'

# %%
print(it_companies)
# Out:
# ['GOOGLE', 'Microsoft', 'Apple', 'IBM', 'Oracle', 'Amazon', 'Mitsubichi', 'Honda']

# %%
# Remove the middle IT company or companies from the list
it_companies.pop(len(it_companies)//2)
# Out:
# 'Oracle'

# %%
# Remove the last IT company from the list
it_companies.pop(-1)
# Out:
# 'Honda'

# %%
# Remove all IT companies from the list
die_list = it_companies.copy()
die_list.clear()

print(die_list)
# Out:
# []

# %%
# Destroy the IT companies list
# die_list.destroy() -> no existe destroy en list

del die_list

# %%
# Join the following lists:
front_end = ['HTML', 'CSS', 'JS', 'React', 'Redux']
back_end = ['Node','Express', 'MongoDB']

complete_list = (front_end + back_end)
print (complete_list)
# Out:
# ['HTML', 'CSS', 'JS', 'React', 'Redux', 'Node', 'Express', 'MongoDB']

# %%
# After joining the lists in question 26. Copy the joined list and assign it to a variable full_stack, then insert Python and SQL after Redux.
full_stack = complete_list.copy()
index = full_stack.index("Redux")

full_stack.insert(index+1, "Python")
full_stack.insert(index+2, "SQL")

print(full_stack)
# Out:
# ['HTML', 'CSS', 'JS', 'React', 'Redux', 'Python', 'SQL', 'Node', 'Express', 'MongoDB']

# %%
# Exercises: Level 2

# %%
# The following is a list of 10 students ages:
ages = [19, 22, 19, 24, 20, 25, 26, 24, 25, 24]

# %%
# Sort the list and find the min and max age
ages.sort()
print(ages)
# Out:
# [19, 19, 20, 22, 24, 24, 24, 25, 25, 26]

# %%
min(ages)
# Out:
# 19

# %%
max(ages)
# Out:
# 26

# %%
# Add the min age and the max age again to the list
ages.append(19)
ages.append(26)

# %%
print(ages)
# Out:
# [19, 19, 20, 22, 24, 24, 24, 25, 25, 26, 19, 26]

# %%
# Find the median age (one middle item or two middle items divided by two)
median_age = ages[len(ages)//2]
print(median_age)
# Out:
# 24

# %%
# Find the average age (sum of all items divided by their number )
average_age = sum(ages) / len(ages)
print(average_age)
# Out:
# 22.75

# %%
# Find the range of the ages (max minus min)
range_age = max(ages) - min(ages)
print(range_age)
# Out:
# 7

# %%
# Compare the value of (min - average) and (max - average), use abs() method
min_diff = abs(min(ages) - average_age)
max_diff = abs(max(ages) - average_age)

print(min_diff)
print(max_diff)
# Out:
# 3.75
# 3.25

# %%
# Find the middle country(ies) in the countries list

# %%
# Divide the countries list into two equal lists if it is even if not one more country for the first half.
#['China', 'Russia', 'USA', 'Finland', 'Sweden', 'Norway', 'Denmark']. #Unpack the first three countries and the rest as scandic countries.

china, russia, usa, *scandic_countries = ['China', 'Russia', 'USA', 'Finland', 'Sweden', 'Norway', 'Denmark'] # toma lo que hay en la lista y metelo en una nueva lsta llamada...
print(china)
print(russia)
print(usa)
print(scandic_countries)
# Out:
# China
# Russia
# USA
# ['Finland', 'Sweden', 'Norway', 'Denmark']

# %%
# 🎉 CONGRATULATIONS ! 🎉
